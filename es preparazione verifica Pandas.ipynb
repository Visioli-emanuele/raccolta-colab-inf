# %%
import pandas as pd
df= pd.read_csv("https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/anagrafica-vaccini-summary-latest.csv")
df
# Out:
#   fascia_anagrafica    totale  ...  dose_booster  ultimo_aggiornamento
# 0             12-19   6268693  ...           229            2021-10-28
# 1             20-29   9891343  ...         25607            2021-10-28
# 2             30-39  10555697  ...         38989            2021-10-28
# 3             40-49  13761536  ...         49934            2021-10-28
# 4             50-59  15818591  ...         71049            2021-10-28
# 5             60-69  12875027  ...         90443            2021-10-28
# 6             70-79  10840433  ...         60543            2021-10-28
# 7             80-89   7541357  ...        586807            2021-10-28
# 8               90+   1721375  ...        130540            2021-10-28
#
# [9 rows x 10 columns]

# %% [markdown]
# aggingi una colonna chiamata percentuale maschi che contenga la percuale di maschi vaccianti

# %%
df["percentuale_maschi"]=df["sesso_maschile"]/df["totale"]*100 
df
# Out:
#   fascia_anagrafica    totale  ...  ultimo_aggiornamento  percentuale_maschi
# 0             12-19   6268693  ...            2021-10-28           51.198137
# 1             20-29   9891343  ...            2021-10-28           52.285296
# 2             30-39  10555697  ...            2021-10-28           51.351199
# 3             40-49  13761536  ...            2021-10-28           49.626706
# 4             50-59  15818591  ...            2021-10-28           49.060077
# 5             60-69  12875027  ...            2021-10-28           48.522609
# 6             70-79  10840433  ...            2021-10-28           46.970698
# 7             80-89   7541357  ...            2021-10-28           41.746572
# 8               90+   1721375  ...            2021-10-28           29.916375
#
# [9 rows x 11 columns]

# %% [markdown]
# visualizzare il numero totale di persone vaccinate con la seconda dose

# %%
df["seconda_dose"].sum()
# Out:
# 41434957

# %% [markdown]
# eliminare le colonne sesso maschile e femminile

# %%
#del df["sesso_maschile"] #cancella una singola colonna
df=df.drop(columns=["sesso_maschile","sesso_femminile"])
df
# Out:
#   fascia_anagrafica    totale  ...  ultimo_aggiornamento  percentuale_maschi
# 0             12-19   6268693  ...            2021-10-28           51.198137
# 1             20-29   9891343  ...            2021-10-28           52.285296
# 2             30-39  10555697  ...            2021-10-28           51.351199
# 3             40-49  13761536  ...            2021-10-28           49.626706
# 4             50-59  15818591  ...            2021-10-28           49.060077
# 5             60-69  12875027  ...            2021-10-28           48.522609
# 6             70-79  10840433  ...            2021-10-28           46.970698
# 7             80-89   7541357  ...            2021-10-28           41.746572
# 8               90+   1721375  ...            2021-10-28           29.916375
#
# [9 rows x 9 columns]

# %% [markdown]
# cancellare le righe dalla 2 alla 6

# %%
df=df.drop(range(2,7)) #cancello le righe dalla 2 alla 6
df
# Out:
#   fascia_anagrafica   totale  ...  ultimo_aggiornamento  percentuale_maschi
# 0             12-19  6268693  ...            2021-10-28           51.198137
# 1             20-29  9891343  ...            2021-10-28           52.285296
# 7             80-89  7541357  ...            2021-10-28           41.746572
# 8               90+  1721375  ...            2021-10-28           29.916375
#
# [4 rows x 11 columns]

# %% [markdown]
# visualizzare i vaccianti della fascia 20-29

# %%
df[df.fascia_anagrafica=="20-29"] ["totale"]
# Out:
# 1    9891343
# Name: totale, dtype: int64

# %%
df=df.set_index("fascia_anagrafica")
df
# Out:
#                      totale  sesso_maschile  ...  dose_booster  ultimo_aggiornamento
# fascia_anagrafica                            ...
# 12-19               6268693         3209454  ...           229            2021-10-28
# 20-29               9891343         5171718  ...         25607            2021-10-28
# 30-39              10555697         5420477  ...         38989            2021-10-28
# 40-49              13761536         6829397  ...         49934            2021-10-28
# 50-59              15818591         7760613  ...         71049            2021-10-28
# 60-69              12875027         6247299  ...         90443            2021-10-28
# 70-79              10840433         5091827  ...         60543            2021-10-28
# 80-89               7541357         3148258  ...        586807            2021-10-28
# 90+                 1721375          514973  ...        130540            2021-10-28
#
# [9 rows x 9 columns]

# %%
df.loc["20-29","totale"]
# Out:
# 9891343

# %% [markdown]
# sostituire al valoore "90+" il valore 90-120

# %%
df=df[df.fascia_anagrafica=="90+"]
