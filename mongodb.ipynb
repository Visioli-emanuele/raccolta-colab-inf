# %%
import pymongo
import pandas as pd

# %%
client= pymongo.MongoClient("mongodb://Emanuele-Visioli:EMAnuele25102004@cluster0-shard-00-00.x7fma.mongodb.net:27017,cluster0-shard-00-01.x7fma.mongodb.net:27017,cluster0-shard-00-02.x7fma.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-566dc8-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.Visioli # nome del database
db

# %%
df = pd.DataFrame.from_records(db.Prime.find())
df
# Out:
#                           _id                    S  ... IMDb rating Age of viewers
# 0    6193d240f18594bb953bff5b    {'no': {'': '6'}}  ...         8.3            18+
# 1    6193d240f18594bb953bff57    {'no': {'': '2'}}  ...         8.1            16+
# 2    6193d240f18594bb953bff5d    {'no': {'': '8'}}  ...         8.5            18+
# 3    6193d240f18594bb953bff5f   {'no': {'': '10'}}  ...           8            16+
# 4    6193d240f18594bb953bff62   {'no': {'': '13'}}  ...         8.7            18+
# ..                        ...                  ...  ...         ...            ...
# 399  6193d240f18594bb953c00cd  {'no': {'': '376'}}  ...         4.5            13+
# 400  6193d240f18594bb953c00da  {'no': {'': '389'}}  ...         NaN            16+
# 401  6193d240f18594bb953c00e0  {'no': {'': '395'}}  ...         NaN            NaN
# 402  6193d240f18594bb953c00e2  {'no': {'': '397'}}  ...         NaN            NaN
# ...

# %%
rest= db.restaurants 
rest
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.x7fma.mongodb.net:27017', 'cluster0-shard-00-02.x7fma.mongodb.net:27017', 'cluster0-shard-00-01.x7fma.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='atlas-566dc8-shard-0', authsource='admin', retrywrites=True, w='majority'), 'Visioli'), 'restaurants')

# %%
import pandas as pd
df = pd.DataFrame.from_records(db.restaurants.find())#trovo tutti i documents dalla collection resturants con .find() e li metto in un dataframe
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1 = pd.DataFrame(list(db.restaurants.find())) #uso il metodo .DataFrame() per creare un dataframe con dentro delle liste (.list()) 
df1.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# nome data base= cognome
# collection= prime
# database fatto da collections
# collections fatte da documents
# ogni documents viene identificato da un id
