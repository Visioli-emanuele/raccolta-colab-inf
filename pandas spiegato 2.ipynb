# %% [markdown]
# 1)

# %%
import pandas as pd
#"nome data frame"= "nome data frame".set_index("colonna desiderata")
#countries["germany": "united Kindom"] #mostro tutte le righe tra i campi selezionati in questo caso la Germania w il Regno Unito
#countries[2:4] # mostra tutte le righe in quella posizione ma come gli array mostra solo la 2 e la 3
#countries.loc["germany","area"] # nel primo campo mettiamo l'indice e nel secondo mettiamo il nome della colonna desiderata
#countries.loc[[France":"Germany"],["area, population"]] # nella primaa parte mettiamo le righe che vogliamo prendere e nella 2° parte noi prendiamo le colonne che vogliamo
#countries.iloc[0:2,1:3] # nel primo posto nelle [] mettiamo le righe e nel secondo posto le colonne divisi dai "," quindi righe 0 e 2 e le colonne 1 e 3 
#countries.loc["Belgium":"Germany","population"]=10 #gli diciamo che nella riga Belgio e Germania la popolazione deve essere 10
#countries.iloc[0:3,1:2]=100 #idem con patate ma  con le posizioni
#contries["area"]>1000000 #controllo che in tutta la colonna il valore sia veero o falso e restituisce vero o falso

# %% [markdown]
# 2)
