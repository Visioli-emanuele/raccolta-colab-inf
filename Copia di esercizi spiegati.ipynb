# %% [markdown]
# 1) scrivere una funzione chiamata media che dati due numeri restituisca la
# media. Utilizzare poi la funzione in un programma che acquisisca dall'utente due numeri e calcoli la media

# %%
#chiedo all'utente di darmi i numeri da notare questo: 
#n1,n2= le variabili che vogliamo (in questo caso 2)
#int= gli diciamo che quello che vogliamo è un intero quindi un numero
#input= è un valore che inserisce l'utente (se non specificahi nulla è una stringa)
n1, n2=int(input("Enter number: ")),int(input("Enter number: "))
#con "def" diciamo che quella è una funzione, media è il nome e valori tra parentesi ci sono i parametri "formali" (che danno forma ma non vengono mai richiamati)
def media(m1,m2):
#con il "return" resituiamo il/i valori che vogliamo dalla funzione 
  return (n1+n2)/2
#=media lo usiamo per richiamare la funzione e i valori tra parentesi sono i valori che passiamo alla funzione
#r una volta che la funzione è terminata prenderà il valore che abbiamo definito col Return
r= media(n1,n2)
#Media= lambda è il modo in qui inizializziamo una funzione di tipo lambda
# n3 e n4 in questo caso sono i nostri parametri formali 
# dopo i ":" gli diciamo cosa fare nella funzione
Media= lambda n3,n4: (n1+n2)/2
print("la media è: ",r)
#possiamo richiamre la funzione anche quanda usciamo il print 
#per farllo basta mettere il nome della funzione (Media in questo caso) e i valori che gli vogliamo passare tra parentesi 
print("la media è: ", Media(n1,n2))
# Out:
# Enter number: 55
# Enter number: 4
# la media è:  29.5
# la media è:  29.5

# %% [markdown]
# 2) scrivere una funzione chiamata piuCorta che date due liste restituisca la lista con meno elementi. Utilizzare poi la funzione in un programma che acquisisca dall'utente due liste e visualizzi gli elementi della lista più corta

# %%
#con "nome della stringa"=[] definiamo una stringa 
#però facendo come qui sotto vediamo la riempiamo  con un bel for 
#il for cicla e continua a chiedere i numeri che vengono poi divisi con gli spazi 
lst= [int(n) for n in input("inserisci i numeri: ").split()]
lst1= [int(n) for n in input("inserisci i numeri: ").split()]
#dichiariamo la funzione
def piuCorta(lstf,lstf1):
  #qui chiediamo alla funzione un controllo:
  #la lunghezza (len) di lst è minore della lunghezza (len) di last1 
  if len(lst)<len(lst1):
    #se sì allora restituisco la prima lista
    return lst
  #se la condizione nel "if" è falsa (quinid lst1 è più corta di lst) allora (straduzione di "else") resitutisco lst1
  else:
    return lst1
con= piuCorta(lst,lst1)
print("la più corta è: ",piuCorta(lst,lst1))

# %% [markdown]
#  3. scrivere una funzione chiamata costruisciLista che dati due numeri interi restituisca la lista formata da tutti i numeri interi compresi tra i due numeri dati. Utilizzare poi la funzione in un programma che acquisisca dall'utente due numeri e visualizzi la lista formata da tutti i numeri interi compresi tra i due numeri dati ma a partire dal più grande fino al più piccolo.

# %%
#chiedo 2 numeri all'utente
n1=int(input("inserire il numero da qui iniziare: "))
n2=int(input("inserire il numero finale: "))
#inizializzo la funzione
def costrusciLista (n1,n2):
  #creo la lista per inserire tutti i numeri tra n1 e n2
  lst3=[]
  #uso un ciclo "for" e gli dico:
  #cicla da i (che per per le varaibili nel "rage" prende il vaore di n1) fino a n2 e gli diciamo di ciclare 1 numero alla volta (grazie al ",1")
  #in range(n1,n2,1)= significa che "i" prende il valore della prima variabile (n1) e cicla aumentadno la "i" fino a che non diventa uguale a "n2" 
  for i in range(n1,n2,1):
    #diciamo al programma di aggiungere a "last3" il valore della "i"
    lst3.append(i)
    #resituiamo "last3"
  return lst3  
bello= costrusciLista(n1,n2)
#inveritamo la lista (esemprio: lista1= 1, 2, 3, 4. dopo il "reverse()" lista1 diventa 4, 3, 2, 1. quindi il primo diventa l'ultimo il penultimo il secondo e così via)
bello.reverse()
print(bello)
# Out:
# inserire il numero da qui iniziare: 7
# inserire il numero finale: 16
# [15, 14, 13, 12, 11, 10, 9, 8, 7]

# %% [markdown]
# 4) scrivere una funzione chiamata valoreAssoluto che dato un numero restituisca il suo valore assoluto. Utilizzare poi questa funzione per determinare il valore assoluto degli elementi di una lista inserita dall'utente.

# %%
#inizializiamo la funzione
def valoreAssoluto(n):
  #controllo che il numero non sia positivo (perché un numero assoluto è il corrispondete positivo di ogni numero negativo)
  if n < 0:
    #trasformo il numero negativo in positvo
    res = n*-1
    return res
  #se il numero è positivo allora restituisco il numero 
  else:
    return n
#crea una lista con "list()", con "map()" faccio sì che tutto quello dentro le parentesi sia rifatto in tutta la lista 
#"int, input()" fa sì che si inserisca un numero inserito dall'utente e "split()" divide tutto quello che inseriamo separando i valori con gli spazzi
L = list(map(int, input().split()))
#faccio si che la lista "c" si riempia tutta (con il map()) di numeri assoluti perché 
#facendo "map(valoreAssoluto,l)" fa sì che per tutti i valori della lista "l" si richiami la funzione "valoreAssoluto" e quindi che poi lo metta nella lista "c"
c = list(map(valoreAssoluto,L))
print(c)

# %% [markdown]
# 5) scrivere una funzione chiamata scambia che data una lista scambi il primo elemento con l'ultimo, il secondo con il penultimo e così via. Utilizzare poi la funzione in un programma che acquisisca dall'utente una lista di 10 elementi e li visualizzi scambiati.

# %%
#riempiamo una lista
lst4= [int(n) for n in input("inserisci i numeri (max 10): ").split()]
#inizializziamo una funzione
def scambia(stl):
  #scambiamo tutti i valori della lista
  lst4.reverse()
  return lst4
scb= scambia(lst4)
print(scb)
# Out:
# inserisci i numeri (max 10): 1 3 7 10
# [10, 7, 3, 1]

# %% [markdown]
# 6) scrivere una funzione lambda che dati due numeri calcoli la loro somma. Utilizzare la funzione in un programma che chieda all'utente due numeri interi e visualizzi la loro somma.

# %%
#chiediamo 2 numeri all'utente
n1=int(input("inserire il numero da qui iniziare: "))
n2=int(input("inserire il numero finale: "))
#usiamo una funzione lambda con i 2 valori per sapere la somma 
somma= lambda n1,n2: n1 + n2
print(somma(n1,n2))
# Out:
# inserire il numero da qui iniziare: 10
# inserire il numero finale: 7
# 17

# %% [markdown]
# 7) scrivere un programma che utilizzi una lambda function per aumentare di 10 unità tutti gli elementi di una lista di interi inserita dall'utente.

# %%
#riempiamo una lista coi numeri inseriti dall'utente
lst= [int(n) for n in input("inserisci i numeri: ").split()]
#usiamo una funzione lambda per aumente UN numero 
aumento= lambda n1: n1+10
#facciamo sì che col "map()" tutta la lista sia modifica dalla funzione lambda 
lst2=[list(map(aumento,lst))]  
print (lst2)
